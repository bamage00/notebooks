# %%
import quandl as qd
import pandas as pd

# %%
qd.ApiConfig.api_key="FkxogifyHafJvyCfabAg"

# %%
fig_size_1 = (12, 4)

# %%
# df_indicators = qd.get_table('SHARADAR/INDICATORS', table='SF1')
df_indicators = pd.read_csv('D://Notebooks/data/quandl_data/SHARADAR_INDICATORS_c41c38a0aaed171169bb790c5b4b459a.csv')
df_indicators
# Out:
#        table      indicator isfilter isprimarykey  \
# 0        SF1        revenue        N            N
# 1        SF1            cor        N            N
# 2        SF1           sgna        N            N
# 3        SF1            rnd        N            N
# 4        SF1           opex        N            N
# ..       ...            ...      ...          ...
# 313  TICKERS  lastpricedate        N            N
# 314  TICKERS   firstquarter        N            N
# 315  TICKERS    lastquarter        N            N
# 316  TICKERS     secfilings        N            N
# 317  TICKERS    companysite        N            N
#
#                                           title  \
# 0                                      Revenues
# 1                               Cost of Revenue
# 2    Selling General and Administrative Expense
# 3              Research and Development Expense
# 4                            Operating Expenses
# ..                                          ...
# ...

# %%
for i in df_indicators['indicator'].tolist():
    print(i, '\n',
          df_indicators[df_indicators['indicator'] == i]['title'].tolist()[0], '\n',
          df_indicators[df_indicators['indicator'] == i]['description'].tolist()[0], '\n')
# Out:
# revenue
#  Revenues
#  [Income Statement] Amount of Revenue recognized from goods sold; services rendered; insurance premiums; or other activities that constitute an earning process. Interest income for financial institutions is reported net of interest expense and provision for credit losses.
#
# cor
#  Cost of Revenue
#  [Income Statement] The aggregate cost of goods produced and sold and services rendered during the reporting period.
#
# sgna
#  Selling General and Administrative Expense
# ...

# %%
# data = qd.get_table('SHARADAR/SF1', ticker=['AAPL'])
data = pd.read_csv('D://Notebooks/data/quandl_data/SHARADAR_SF1_88f2238a22f557183a542f4114c8b4a7.csv')
data
# Out:
#     ticker dimension calendardate     datekey reportperiod lastupdated  \
# 0     AAPL       MRY   2011-12-31  2011-09-24   2011-09-24  2020-12-09
# 1     AAPL       MRY   2012-12-31  2012-09-29   2012-09-29  2020-12-09
# 2     AAPL       MRY   2013-12-31  2013-09-28   2013-09-28  2020-12-09
# 3     AAPL       MRY   2014-12-31  2014-09-27   2014-09-27  2020-12-09
# 4     AAPL       MRY   2015-12-31  2015-09-26   2015-09-26  2020-12-09
# ..     ...       ...          ...         ...          ...         ...
# 235    XOM       MRY   2014-12-31  2014-12-31   2014-12-31  2020-11-04
# 236    XOM       MRY   2015-12-31  2015-12-31   2015-12-31  2020-11-04
# 237    XOM       MRY   2016-12-31  2016-12-31   2016-12-31  2020-11-04
# 238    XOM       MRY   2017-12-31  2017-12-31   2017-12-31  2020-11-04
# 239    XOM       MRY   2018-12-31  2018-12-31   2018-12-31  2020-11-04
#
#           accoci        assets     assetsavg       assetsc  ...    sharesbas  \
# ...

# %%
data_filtered = data[data['ticker'] == 'AAPL']
data_filtered
# Out:
#   ticker dimension calendardate     datekey reportperiod lastupdated  \
# 0   AAPL       MRY   2011-12-31  2011-09-24   2011-09-24  2020-12-09
# 1   AAPL       MRY   2012-12-31  2012-09-29   2012-09-29  2020-12-09
# 2   AAPL       MRY   2013-12-31  2013-09-28   2013-09-28  2020-12-09
# 3   AAPL       MRY   2014-12-31  2014-09-27   2014-09-27  2020-12-09
# 4   AAPL       MRY   2015-12-31  2015-09-26   2015-09-26  2020-12-09
# 5   AAPL       MRY   2016-12-31  2016-09-24   2016-09-24  2020-12-09
# 6   AAPL       MRY   2017-12-31  2017-09-30   2017-09-30  2020-12-09
# 7   AAPL       MRY   2018-12-31  2018-09-29   2018-09-29  2020-12-09
#
#        accoci        assets     assetsavg       assetsc  ...    sharesbas  \
# 0   443000000  116371000000  101193750000  4.498800e+10  ...  25958544808
# 1   499000000  176064000000  157143750000  5.765300e+10  ...  26247368000
# 2  -471000000  207000000000  199421750000  7.328600e+10  ...  25437916000
# ...

# %%
metrics = ['revenue', 'netinc', 'epsdil', 'shareswadil', 'capex', 'ncf', 'assets', 'cashneq', 'liabilities', 'equity',
           'debt', 'ebitda', 'dps', 'ev', 'roe', 'roa', 'fcf', 'gp', 'opinc', 'grossmargin', 'netmargin', 'pe', 'ps',
           'pb', 'de', 'divyield']

for m in metrics:
    data_filtered.plot(x='datekey', y=[m , 'marketcap'], secondary_y=['marketcap'], style=['-', '--'],
              grid=True, figsize=fig_size_1, title=m)
# Out:
# c:\users\siddh\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
